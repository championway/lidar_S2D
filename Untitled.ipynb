# %%
import cv2
import numpy as np
import math
from PIL import Image
import matplotlib.pyplot as plt

img_path = "/media/arg_ws3/5E703E3A703E18EB/data/lidar_S2D/pcl_16/house/img_75.png"
img_path = "gray.png"

# %%
lidar_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# %%
lidar_img.shape
# Out:
# (512, 512)

# %%
max(lidar_img[lidar_img!=0]/655.)
# Out:
# 0.042748091603053436

# %%
img_A = Image.open(img_path)
img_A = np.array(img_A)/655.

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(10, 10))
dilated = cv2.dilate(img_A, kernel)

# %%
plt.imshow(dilated)

# %%
blur = cv2.blur(dilated, (10, 10), 0)
plt.imshow(blur)
